# %% [markdown]
# ## EXERCISES
# - elpais 기사로 텍스트 분석한다면...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen('https://elpais.com/babelia/2021-10-25/metidos-hasta-el-cuello-en-la-distopia.html')
bs = BeautifulSoup(html.read(), 'html.parser')
print(bs.h1) # headline
# Out:
# <h1 class="a_t">Bienvenidos a la era de la distopía</h1>

# %%
content = bs.findAll('p', {'class':''})

# %%
data = []
for line in content:
    data.append(line.get_text())
    
data
# Out:
# ['Arranquemos con cifras. The Guardian informó el 17 de septiembre de 2019 de que Los testamentos (Atwood, 2019) había vendido en cinco días más de cien mil copias en Estados Unidos. Traducida a cincuenta y cuatro idiomas, la trilogía Los juegos del hambre (Collins, 2008) lleva vendidos más de cien millones de ejemplares, sin contar los de la precuela, Balada de pájaros cantores y serpientes (Collins, 2020). La versión cinematográfica del primer volumen de la saga recaudó la nada despreciable cantidad de setecientos millones de dólares. Cuantías similares engalanan las novelas Divergente (Roth, 2011) y, algo por debajo, El corredor del laberinto (Dashner, 2009). Tras la llegada a la presidencia de Donald Trump, 1984 (Orwell, 1949) batió récord de ventas. La tónica se reproduce dentro del ámbito televisivo. La serie El cuento de la criada ganó ocho galardones de los premios Emmy en 2017, edición en la que Westworld contaba con hasta veintidós nominaciones, mientras que Black Mirror lideró el rating de audiencia de las plataformas de streaming durante seis semanas de 2018. Al año siguiente, Years and years arrasó en todo el mundo.',
#  'Los marcadores ilustran que a lo largo del siglo XXI la distopía ha dejado de ser una rama de la ciencia ficción atiborrada de títulos minoritarios y agraciada con éxitos dispersos. Se ha convertido en una moda de masas altamente rentable que suministra a los fans multitud de bestsellers, blockbusters y merchandising. Entre los consumidores más recalcitrantes de la marca distopía destacan, con permiso de los boomers de clase media, los millennials, lanzados a la adquisición fogosa de mañanas fallidos, duplicados al infinito a raíz del pelotazo comercial de Los juegos del hambre. No hay duda, visto lo visto, de que vivimos rodeados de distopías “que enganchan como un opiáceo de Purdue Pharma Inc. o una cuenta de Facebook”. Entretanto, la utopía aparece como un artículo prehistórico y soporífero, procedente de eras remotas. Sin que nadie lo lamente, se disipa.',
#  'La adicción del gran público a las historias distópicas apenas alumbra la superficie de la distopofilia que nos embarga. A poco que hurguemos, descubriremos algo que se antoja menos efímero que la moda en curso: la distopización de la cultura contemporánea. Arrastrados por las cadencias prevalentes, percibimos e interpretamos la realidad distópicamente, persuadidos de sufrir manipulaciones recónditas y de morar en las entrañas de un declive civilizatorio continuo. Siendo esto así, se entiende que en 2019 Emmanuel Macron ordenara al Ministerio de los Ejércitos alistar a escritores de ciencia ficción con el objeto de adelantarse a la aparición de entornos disruptivos. En vez de contratar a esa valiosa gente para discurrir futuros deseables y tácticas para realizarlos, Macron prefirió, extenuado por la ansiedad anticipatoria, prepararse ante males hipotéticos. Actuó igual que los miembros de las élites que destinan sumas multimillonarias a la construcción de refugios privados donde guarecerse cuando las calamidades estallen. E igual, esa es otra, que la sociedad in toto: a expensas del miedo, disparador distópico por antonomasia.',
#  'La distopización de los imaginarios tampoco pasó desapercibida a los estudiosos de la ciencia ficción. Kingsley Amis publicó New Maps of Hell (1960), compilación de ensayos que vinculaba la supremacía distópica a la consternación desatada por la Segunda Guerra Mundial y los regímenes de Hitler y Stalin. Dos años después, Chad Walsh informaba en From Utopia to Nightmare de que “el lector que busque utopías actuales, probablemente las encontrará torpes y poco convincentes. Pero si quiere pesadillas presentadas por expertos, puede elegir entre una variedad de horrores mayor que la descrita por Dante”. Premisas análogas decoraron The Future as Nightmare (1967), de Mark Hillegas, y Science Fiction and the New Dark Age (1976), de Harold Berger. Entre ambos, apareció Historia de la ciencia ficción (1971), del escritor Sam Lundway, donde leemos:',
#  'Muchos escritores de ciencia ficción son unos misántropos incurables. Esto podría ser resultado de una inclinación insólitamente pesimista o de una gran perspicacia, pero lo cierto es que pocos escritores modernos de SF hallan razones para contemplar el futuro con gran esperanza […]. El futuro resultará ser exactamente como nuestra propia época […], solo que peor. Y luego reflejan un infierno sobre la Tierra.',
#  'La cimentación de Distopiland recibió el espaldarazo definitivo el nueve de noviembre de 1989, día en que se produjo la caída del Muro de Berlín. La utopía sufrió una bofetada brutal, pues el lance parecía ratificar que los sueños de perfeccionamiento y emancipación habían fracasado donde más duele, en la práctica. El acontecimiento aglutinó simbólicamente el tropel de fracasos vividos por los movimientos revolucionarios en el pasado, fracasos que, reunidos de golpe, se manifestaron intolerables, humillantes, imposibles de procesar. Nada quedaba ahí de la dignidad y la aureola desprendidas de los reveses previos (Comuna de París, guerra civil española, Mayo del 68, Gobierno de Pinochet), capaces de dispensar orgullo e incitar el afán de revancha. En esta ocasión, la derrota era categórica. Los escombros taponaron el horizonte utópico socialista que había conferido esperanza a millones de personas. Esperanza, a decir verdad, que llegaba menguada a causa de la larga secuencia de desengaños estrenada con la naturaleza totalitaria de la Unión Soviética y prorrogada por la represión de la Primavera de Praga, las matanzas de la Revolución Cultural y el genocidio de Camboya. Quienes en otros lapsos confiaron en transformar el mundo enfermaron de estrés postraumático y sobrevivieron atormentados por el duelo y la culpa. Resentidos y desmoralizados, cooperaron en la desutopización de la conciencia política consolidada aquella jornada, como una venganza tardía por las ilusiones esgrimidas en la juventud.',
#  'Puedes seguir a BABELIA en Facebook y Twitter, o apuntarte aquí para recibir nuestra newsletter semanal.']

# %%
len(data)  # segment
# Out:
# 14

# %% [markdown]
# #### tokenize

# %%
# sentence split
import nltk
sent_tokenizer = nltk.data.load('tokenizers/punkt/spanish.pickle')

# %%
result = sent_tokenizer.tokenize(' '.join(data)) # segment 경계 없앰
result
# Out:
# ['Arranquemos con cifras.',
#  'The Guardian informó el 17 de septiembre de 2019 de que Los testamentos (Atwood, 2019) había vendido en cinco días más de cien mil copias en Estados Unidos.',
#  'Traducida a cincuenta y cuatro idiomas, la trilogía Los juegos del hambre (Collins, 2008) lleva vendidos más de cien millones de ejemplares, sin contar los de la precuela, Balada de pájaros cantores y serpientes (Collins, 2020).',
#  'La versión cinematográfica del primer volumen de la saga recaudó la nada despreciable cantidad de setecientos millones de dólares.',
#  'Cuantías similares engalanan las novelas Divergente (Roth, 2011) y, algo por debajo, El corredor del laberinto (Dashner, 2009).',
#  'Tras la llegada a la presidencia de Donald Trump, 1984 (Orwell, 1949) batió récord de ventas.',
#  'La tónica se reproduce dentro del ámbito televisivo.',
#  'La serie El cuento de la criada ganó ocho galardones de los premios Emmy en 2017, edición en la que Westworld contaba con hasta veintidós nominaciones, mientras que Black Mirror lideró el rating de audiencia de las plataformas de streaming durante seis semanas de 2018.',
#  'Al año siguiente, Years and years arrasó en todo el mundo.',
#  'Los marcadores ilustran que a lo largo del siglo XXI la distopía ha dejado de ser una rama de la ciencia ficción atiborrada de títulos minoritarios y agraciada con éxitos dispersos.',
#  'Se ha convertido en una moda de masas altamente rentable que suministra a los fans multitud de bestsellers, blockbusters y merchandising.',
#  'Entre los consumidores más recalcitrantes de la marca distopía destacan, con permiso de los boomers de clase media, los millennials, lanzados a la adquisición fogosa de mañanas fallidos, duplicados al infinito a raíz del pelotazo comercial de Los juegos del hambre.',
#  'No hay duda, visto lo visto, de que vivimos rodeados de distopías “que enganchan como un opiáceo de Purdue Pharma Inc.',
#  'o una cuenta de Facebook”.',
#  'Entretanto, la utopía aparece como un artículo prehistórico y soporífero, procedente de eras remotas.',
#  'Sin que nadie lo lamente, se disipa.',
#  'La adicción del gran público a las historias distópicas apenas alumbra la superficie de la distopofilia que nos embarga.',
#  'A poco que hurguemos, descubriremos algo que se antoja menos efímero que la moda en curso: la distopización de la cultura contemporánea.',
#  'Arrastrados por las cadencias prevalentes, percibimos e interpretamos la realidad distópicamente, persuadidos de sufrir manipulaciones recónditas y de morar en las entrañas de un declive civilizatorio continuo.',
#  'Siendo esto así, se entiende que en 2019 Emmanuel Macron ordenara al Ministerio de los Ejércitos alistar a escritores de ciencia ficción con el objeto de adelantarse a la aparición de entornos disruptivos.',
#  'En vez de contratar a esa valiosa gente para discurrir futuros deseables y tácticas para realizarlos, Macron prefirió, extenuado por la ansiedad anticipatoria, prepararse ante males hipotéticos.',
#  'Actuó igual que los miembros de las élites que destinan sumas multimillonarias a la construcción de refugios privados donde guarecerse cuando las calamidades estallen.',
#  'E igual, esa es otra, que la sociedad in toto: a expensas del miedo, disparador distópico por antonomasia.',
#  'Desagradable y necesario, el miedo es el “constituyente básico de la subjetividad actual” y “el más siniestro de los múltiples demonios que anidan en las sociedades abiertas de nuestra época”.',
#  'El cambio climático, el auge de la extrema derecha, el agotamiento de los recursos, el aumento de la desigualdad, el terrorismo islamista, el poder de las corporaciones y la precarización laboral lo han aupado a la categoría de turbación omnipresente e indisoluble, cualidades que transfiere a las sensaciones de inseguridad y vulnerabilidad que lo escoltan.',
#  'Claro está, o debería estarlo, que el quid de la cuestión no radica en el miedo en sí mismo, una emoción humana normal.',
#  'Radica en la ubicuidad suprema que ha adquirido, recíproca a su desmedida instrumentalización política.',
#  'Si el miedo siempre sirvió a las órdenes de las ingenierías de control, hoy ese papel se redobla apelando a los más heterogéneos peligros.',
#  'Entre los miedos que se publicitan hay unos cuantos que responden a amenazas objetivas.',
#  'El resto son ideológicos e inducidos.',
#  'El futuro resultará ser exactamente como nuestra propia época […], solo que peor.',
#  'Y luego reflejan un infierno sobre la Tierra.',
#  'La cimentación de Distopiland recibió el espaldarazo definitivo el nueve de noviembre de 1989, día en que se produjo la caída del Muro de Berlín.',
#  'La utopía sufrió una bofetada brutal, pues el lance parecía ratificar que los sueños de perfeccionamiento y emancipación habían fracasado donde más duele, en la práctica.',
#  'El acontecimiento aglutinó simbólicamente el tropel de fracasos vividos por los movimientos revolucionarios en el pasado, fracasos que, reunidos de golpe, se manifestaron intolerables, humillantes, imposibles de procesar.',
#  'Nada quedaba ahí de la dignidad y la aureola desprendidas de los reveses previos (Comuna de París, guerra civil española, Mayo del 68, Gobierno de Pinochet), capaces de dispensar orgullo e incitar el afán de revancha.',
#  'En esta ocasión, la derrota era categórica.',
#  'Los escombros taponaron el horizonte utópico socialista que había conferido esperanza a millones de personas.',
#  'Esperanza, a decir verdad, que llegaba menguada a causa de la larga secuencia de desengaños estrenada con la naturaleza totalitaria de la Unión Soviética y prorrogada por la represión de la Primavera de Praga, las matanzas de la Revolución Cultural y el genocidio de Camboya.',
#  'Quienes en otros lapsos confiaron en transformar el mundo enfermaron de estrés postraumático y sobrevivieron atormentados por el duelo y la culpa.',
#  'Resentidos y desmoralizados, cooperaron en la desutopización de la conciencia política consolidada aquella jornada, como una venganza tardía por las ilusiones esgrimidas en la juventud.',
#  'Puedes seguir a BABELIA en Facebook y Twitter, o apuntarte aquí para recibir nuestra newsletter semanal.']

# %%
result[:5]
# Out:
# ['Arranquemos con cifras.',
#  'The Guardian informó el 17 de septiembre de 2019 de que Los testamentos (Atwood, 2019) había vendido en cinco días más de cien mil copias en Estados Unidos.',
#  'Traducida a cincuenta y cuatro idiomas, la trilogía Los juegos del hambre (Collins, 2008) lleva vendidos más de cien millones de ejemplares, sin contar los de la precuela, Balada de pájaros cantores y serpientes (Collins, 2020).',
#  'La versión cinematográfica del primer volumen de la saga recaudó la nada despreciable cantidad de setecientos millones de dólares.',
#  'Cuantías similares engalanan las novelas Divergente (Roth, 2011) y, algo por debajo, El corredor del laberinto (Dashner, 2009).']

# %% [markdown]
# #### word_tokenize + stopwords

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('spanish')

# %%
import spacy
nlp = spacy.load('es_core_news_sm')

# %%
sample = [nlp(sentence) for sentence in result]

token_list = []
token_list_all = []

for sentence in sample:
    tokens = [str(token).lower() for token in sentence] # type 바꿔주어야 함.
    eliminated_tokens = [word for word in tokens  if word not in stop_words] 
    #print(eliminated_tokens)
    #print('토큰 길이= ', len(tokens), len(eliminated_tokens), '\n')
    
    token_list.append(eliminated_tokens) # 문장 경계 있는
    token_list_all.extend(eliminated_tokens) # 문장 경계 없는

# %%
len(token_list)
# Out:
# 81

# %%
token_list
# Out:
# [['arranquemos', 'cifras', '.'],
#  ['the',
#   'guardian',
#   'informó',
#   '17',
#   'septiembre',
#   '2019',
#   'testamentos',
#   '(',
#   'atwood',
#   ',',
#   '2019',
#   ')',
#   'vendido',
#   'cinco',
#   'días',
#   'cien',
#   'mil',
#   'copias',
#   'unidos',
#   '.'],
#  ['traducida',
#   'cincuenta',
#   'cuatro',
#   'idiomas',
#   ',',
#   'trilogía',
#   'juegos',
#   'hambre',
#   '(',
#   'collins',
#   ',',
#   '2008',
#   ')',
#   'lleva',
#   'vendidos',
#   'cien',
#   'millones',
#   'ejemplares',
#   ',',
#   'contar',
#   'precuela',
#   ',',
#   'balada',
#   'pájaros',
#   'cantores',
#   'serpientes',
#   '(',
#   'collins',
#   ',',
#   '2020',
#   ')',
#   '.'],
#  ['versión',
#   'cinematográfica',
#   'primer',
#   'volumen',
#   'saga',
#   'recaudó',
#   'despreciable',
#   'cantidad',
#   'setecientos',
#   'millones',
#   'dólares',
#   '.'],
#  ['cuantías',
#   'similares',
#   'engalanan',
#   'novelas',
#   'divergente',
#   '(',
#   'roth',
#   ',',
#   '2011',
#   ')',
#   ',',
#   'debajo',
#   ',',
#   'corredor',
#   'laberinto',
#   '(',
#   'dashner',
#   ',',
#   '2009',
#   ')',
#   '.'],
#  ['tras',
#   'llegada',
#   'presidencia',
#   'donald',
#   'trump',
#   ',',
#   '1984',
#   '(',
#   'orwell',
#   ',',
#   '1949',
#   ')',
#   'batió',
#   'récord',
#   'ventas',
#   '.'],
#  ['tónica', 'reproduce', 'dentro', 'ámbito', 'televisivo', '.'],
#  ['serie',
#   'cuento',
#   'criada',
#   'ganó',
#   'ocho',
#   'galardones',
#   'premios',
#   'emmy',
#   '2017',
#   ',',
#   'edición',
#   'westworld',
#   'contaba',
#   'veintidós',
#   'nominaciones',
#   ',',
#   'mientras',
#   'black',
#   'mirror',
#   'lideró',
#   'rating',
#   'audiencia',
#   'plataformas',
#   'streaming',
#   'seis',
#   'semanas',
#   '2018',
#   '.'],
#  ['año', 'siguiente', ',', 'years', 'and', 'years', 'arrasó', 'mundo', '.'],
#  ['marcadores',
#   'ilustran',
#   'largo',
#   'siglo',
#   'xxi',
#   'distopía',
#   'dejado',
#   'ser',
#   'rama',
#   'ciencia',
#   'ficción',
#   'atiborrada',
#   'títulos',
#   'minoritarios',
#   'agraciada',
#   'éxitos',
#   'dispersos',
#   '.'],
#  ['convertido',
#   'moda',
#   'masas',
#   'altamente',
#   'rentable',
#   'suministra',
#   'fans',
#   'multitud',
#   'bestsellers',
#   ',',
#   'blockbusters',
#   'merchandising',
#   '.'],
#  ['consumidores',
#   'recalcitrantes',
#   'marca',
#   'distopía',
#   'destacan',
#   ',',
#   'permiso',
#   'boomers',
#   'clase',
#   'media',
#   ',',
#   'millennials',
#   ',',
#   'lanzados',
#   'adquisición',
#   'fogosa',
#   'mañanas',
#   'fallidos',
#   ',',
#   'duplicados',
#   'infinito',
#   'raíz',
#   'pelotazo',
#   'comercial',
#   'juegos',
#   'hambre',
#   '.'],
#  ['duda',
#   ',',
#   'visto',
#   'visto',
#   ',',
#   'vivimos',
#   'rodeados',
#   'distopías',
#   '“',
#   'enganchan',
#   'opiáceo',
#   'purdue',
#   'pharma',
#   'inc',
#   '.'],
#  ['cuenta', 'facebook', '”', '.'],
#  ['entretanto',
#   ',',
#   'utopía',
#   'aparece',
#   'artículo',
#   'prehistórico',
#   'soporífero',
#   ',',
#   'procedente',
#   'remotas',
#   '.'],
#  ['nadie', 'lamente', ',', 'disipa', '.'],
#  ['adicción',
#   'gran',
#   'público',
#   'historias',
#   'distópicas',
#   'apenas',
#   'alumbra',
#   'superficie',
#   'distopofilia',
#   'embarga',
#   '.'],
#  ['hurguemos',
#   ',',
#   'descubriremos',
#   'antoja',
#   'menos',
#   'efímero',
#   'moda',
#   'curso',
#   ':',
#   'distopización',
#   'cultura',
#   'contemporánea',
#   '.'],
#  ['arrastrados',
#   'cadencias',
#   'prevalentes',
#   ',',
#   'percibimos',
#   'interpretamos',
#   'realidad',
#   'distópicamente',
#   ',',
#   'persuadidos',
#   'sufrir',
#   'manipulaciones',
#   'recónditas',
#   'morar',
#   'entrañas',
#   'declive',
#   'civilizatorio',
#   'continuo',
#   '.'],
#  ['siendo',
#   'así',
#   ',',
#   'entiende',
#   '2019',
#   'emmanuel',
#   'macron',
#   'ordenara',
#   'ministerio',
#   'ejércitos',
#   'alistar',
#   'escritores',
#   'ciencia',
#   'ficción',
#   'objeto',
#   'adelantarse',
#   'aparición',
#   'entornos',
#   'disruptivos',
#   '.'],
#  ['vez',
#   'contratar',
#   'valiosa',
#   'gente',
#   'discurrir',
#   'futuros',
#   'deseables',
#   'tácticas',
#   'realizarlos',
#   ',',
#   'macron',
#   'prefirió',
#   ',',
#   'extenuado',
#   'ansiedad',
#   'anticipatoria',
#   ',',
#   'prepararse',
#   'males',
#   'hipotéticos',
#   '.'],
#  ['actuó',
#   'igual',
#   'miembros',
#   'élites',
#   'destinan',
#   'sumas',
#   'multimillonarias',
#   'construcción',
#   'refugios',
#   'privados',
#   'guarecerse',
#   'calamidades',
#   'estallen',
#   '.'],
#  ['igual',
#   ',',
#   ',',
#   'sociedad',
#   'in',
#   'toto',
#   ':',
#   'expensas',
#   'miedo',
#   ',',
#   'disparador',
#   'distópico',
#   'antonomasia',
#   '.'],
#  ['desagradable',
#   'necesario',
#   ',',
#   'miedo',
#   '“',
#   'constituyente',
#   'básico',
#   'subjetividad',
#   'actual',
#   '”',
#   '“',
#   'siniestro',
#   'múltiples',
#   'demonios',
#   'anidan',
#   'sociedades',
#   'abiertas',
#   'época',
#   '”',
#   '.'],
#  ['cambio',
#   'climático',
#   ',',
#   'auge',
#   'extrema',
#   'derecha',
#   ',',
#   'agotamiento',
#   'recursos',
#   ',',
#   'aumento',
#   'desigualdad',
#   ',',
#   'terrorismo',
#   'islamista',
#   ',',
#   'poder',
#   'corporaciones',
#   'precarización',
#   'laboral',
#   'aupado',
#   'categoría',
#   'turbación',
#   'omnipresente',
#   'indisoluble',
#   ',',
#   'cualidades',
#   'transfiere',
#   'sensaciones',
#   'inseguridad',
#   'vulnerabilidad',
#   'escoltan',
#   '.'],
#  ['claro',
#   ',',
#   'debería',
#   'estarlo',
#   ',',
#   'quid',
#   'cuestión',
#   'radica',
#   'miedo',
#   'mismo',
#   ',',
#   'emoción',
#   'humana',
#   'normal',
#   '.'],
#  ['radica',
#   'ubicuidad',
#   'suprema',
#   'adquirido',
#   ',',
#   'recíproca',
#   'desmedida',
#   'instrumentalización',
#   'política',
#   '.'],
#  ['si',
#   'miedo',
#   'siempre',
#   'sirvió',
#   'órdenes',
#   'ingenierías',
#   'control',
#   ',',
#   'hoy',
#   'papel',
#   'redobla',
#   'apelando',
#   'heterogéneos',
#   'peligros',
#   '.'],
#  ['miedos',
#   'publicitan',
#   'cuantos',
#   'responden',
#   'amenazas',
#   'objetivas',
#   '.'],
#  ['resto', 'ideológicos', 'inducidos', '.'],
#  ['sienten',
#   'miedo',
#   'destrucción',
#   'planeta',
#   ',',
#   'llegada',
#   'inmigrantes',
#   ',',
#   'pérdida',
#   'empleo',
#   ',',
#   'degeneración',
#   'costumbres',
#   ',',
#   'alimentos',
#   'transgénicos',
#   ',',
#   'avance',
#   'feminismo',
#   ',',
#   'gobiernos',
#   'retrógrados',
#   'ocupación',
#   'viviendas',
#   '.'],
#  ['día', 'día', 'revolotea', 'alrededor', 'miedo', '.'],
#  ['atentados',
#   'torres',
#   'gemelas',
#   '2001',
#   'bancarrota',
#   'financiera',
#   '2008',
#   'amplificaron',
#   'incidencia',
#   'social',
#   'usos',
#   'políticos',
#   'miedo',
#   '.'],
#  ['pavor',
#   'despertado',
#   'futuro',
#   'hacía',
#   'bastantes',
#   'décadas',
#   'ensanchó',
#   'desmesura',
#   '.'],
#  ['deriva',
#   'milenarista',
#   'fin',
#   'siècle',
#   'exhibida',
#   'puertas',
#   '2000',
#   'anticipo',
#   'iba',
#   'llegar',
#   ':',
#   'época',
#   'desencanto',
#   'malestar',
#   'futuro',
#   'pierde',
#   'aureola',
#   'degenera',
#   'territorio',
#   'hostil',
#   ',',
#   'poblado',
#   'peores',
#   'pesadillas',
#   'presagios',
#   ',',
#   'atravesado',
#   'sentir',
#   'fechorías',
#   ',',
#   'vicios',
#   'egoísmos',
#   'van',
#   'ser',
#   'castigados',
#   '.'],
#  ['dos',
#   'décadas',
#   'tarde',
#   ',',
#   'testamos',
#   'ambiente',
#   'todavía',
#   'desilusionado',
#   ',',
#   'subyugado',
#   '“',
#   'fascinación',
#   'apocalipsis',
#   '”',
#   'impresión',
#   'vivir',
#   'tiempos',
#   'prórroga',
#   ',',
#   'ubicados',
#   'después',
#   'después',
#   ',',
#   'antesala',
#   'condena',
#   'terminal',
#   ',',
#   'mañana',
#   'orbe',
#   'colapsará',
#   'sopetón',
#   '.'],
#  ['nótese',
#   ',',
#   'cabría',
#   'puntualizar',
#   ',',
#   'cómo',
#   'alocuciones',
#   'integristas',
#   'fijación',
#   'apocalíptica',
#   'curso',
#   'difieren',
#   'tradicional',
#   '.'],
#  ['apocalipsis',
#   'antiguos',
#   'incluían',
#   'expectativa',
#   'mesiánica',
#   'tras',
#   'correctivo',
#   'impartido',
#   'gran',
#   'hecatombe',
#   'surgiría',
#   'regeneración',
#   'universo',
#   'purificado',
#   'maldades',
#   'pretéritas',
#   '.'],
#  ['esperanza', 'miedo', 'sustentaban', 'recíprocamente', '.'],
#  ['cambio',
#   ',',
#   'apocalipsis',
#   'presente',
#   'carece',
#   'gratificación',
#   'posterior',
#   'castigo',
#   '.'],
#  ['pronuncia', 'versos', 'puro', 'final', '.'],
#  ['murmullos',
#   'suenan',
#   'quejidos',
#   'infecundos',
#   'bulevares',
#   'distopiland',
#   '.'],
#  ['filósofo',
#   'estadounidense',
#   'fredric',
#   'jameson',
#   'afirma',
#   'vínculo',
#   'establecido',
#   'marcada',
#   'disminución',
#   'nuevas',
#   'utopías',
#   'aumento',
#   'exagerado',
#   'tipo',
#   'distopías',
#   'concebibles',
#   'viene',
#   'despuntando',
#   'últimas',
#   'décadas',
#   '.'],
#  ['dicha',
#   'relación',
#   ',',
#   'permito',
#   'corregir',
#   ',',
#   'remonta',
#   'atrás',
#   'tiempo',
#   '.'],
#  ['si',
#   'bien',
#   'incontestable',
#   'mitomanía',
#   'distópica',
#   'atentados',
#   '2001',
#   'crisis',
#   '2008',
#   'interruptores',
#   ',',
#   'menos',
#   'verdad',
#   'remacha',
#   'tendencias',
#   'previas',
#   ',',
#   'alimentadas',
#   'miedos',
#   'florecieron',
#   'siglos',
#   'xix',
#   'xx',
#   '.'],
#  ['desencanto',
#   'promesas',
#   'ilustradas',
#   'industrialización',
#   'dieron',
#   'pie',
#   'ataques',
#   ',',
#   'ideológicamente',
#   'dispares',
#   ',',
#   'románticos',
#   'decimonónicos',
#   'zivilisation',
#   ',',
#   'nomenclatura',
#   'designaba',
#   'sociedad',
#   'mecanicista',
#   ',',
#   'urbana',
#   ',',
#   'cientificista',
#   'individualista',
#   'sustituyendo',
#   'kultur',
#   'orgánica',
#   ',',
#   'rural',
#   ',',
#   'espiritual',
#   'comunitaria',
#   '.'],
#  ['ojos',
#   'numerosos',
#   'intelectuales',
#   'momento',
#   ',',
#   'llegada',
#   'zivilisation',
#   'condenaba',
#   'hombres',
#   'existencia',
#   'superficial',
#   ',',
#   'degradada',
#   'impersonal',
#   ',',
#   'occidente',
#   'cruzar',
#   '“',
#   'proceso',
#   'deterioro',
#   ',',
#   'agotamiento',
#   'colapso',
#   'inevitable',
#   '”',
#   '.'],
#  ['costumbre',
#   'tachar',
#   'sociedades',
#   'occidentales',
#   'decadentes',
#   'enfermas',
#   'facciones',
#   'antimodernas',
#   '/',
#   'victorianas',
#   'xix',
#   'fuente',
#   ',',
#   'igual',
#   'distopía',
#   'misma',
#   ',',
#   'germinó',
#   'entonces',
#   '.'],
#  ['primera',
#   'guerra',
#   'mundial',
#   'gran',
#   'depresión',
#   'ensancharon',
#   'influjo',
#   'pesimismo',
#   'cultural',
#   'facilitaron',
#   'incipientes',
#   'distopías',
#   'ganaran',
#   'adeptos',
#   'reputación',
#   '.'],
#  ['eruditos',
#   'despechados',
#   'década',
#   '1930',
#   ',',
#   '“',
#   'primera',
#   'guerra',
#   'mundial',
#   ',',
#   'ascenso',
#   'fascismo',
#   ',',
#   'degeneración',
#   'comunismo',
#   'soviético',
#   'estalinismo',
#   'fracaso',
#   'capitalismo',
#   'occidental',
#   '[',
#   '…',
#   ']',
#   'comentarios',
#   'burlones',
#   'lanzados',
#   'esperanzas',
#   'utópicas',
#   '”',
#   '.'],
#  ['ánimo', 'firmemente', 'distópico', '.'],
#  ['terminar',
#   'segunda',
#   'guerra',
#   'mundial',
#   ',',
#   'totalitarismos',
#   ',',
#   'bombas',
#   'atómicas',
#   ',',
#   'genocidios',
#   ',',
#   'gulag',
#   'violencia',
#   'ocupando',
#   'primer',
#   'plano',
#   'discusión',
#   ',',
#   'distopía',
#   'acaparaba',
#   'estrellato',
#   ',',
#   'utopía',
#   ',',
#   'cuyas',
#   'presencias',
#   'editoriales',
#   'descendieron',
#   'mínimos',
#   'históricos',
#   ',',
#   'rozar',
#   'nunca',
#   'resonancia',
#   'obtenida',
#   'edward',
#   'bellamy',
#   ',',
#   'étienne',
#   'cabet',
#   'h.',
#   'g.',
#   'wells',
#   '.'],
#  ['dinámicas',
#   'cambiarían',
#   'adelante',
#   ',',
#   'siquiera',
#   'lapso',
#   '1974-1976',
#   ',',
#   'feminismo',
#   ',',
#   'ecologismo',
#   'contracultura',
#   'espolearon',
#   'escritura',
#   'desposeídos',
#   '(',
#   'guin',
#   ',',
#   '1974',
#   ')',
#   ',',
#   'ecotopía',
#   '(',
#   'callenbach',
#   ',',
#   '1975',
#   ')',
#   ',',
#   'hombre',
#   'hembra',
#   '(',
#   'russ',
#   ',',
#   '1975',
#   ')',
#   'mujer',
#   'borde',
#   'tiempo',
#   '(',
#   'piercy',
#   ',',
#   '1976',
#   ')',
#   ',',
#   'utopías',
#   'cruciales',
#   'renovación',
#   'género',
#   '.'],
#  ['importancia',
#   'puede',
#   'hacernos',
#   'perder',
#   'vista',
#   'distopías',
#   'ganaron',
#   'cuantitativa',
#   'cualitativamente',
#   'goleada',
#   'idénticas',
#   'fechas',
#   ',',
#   'mientras',
#   'lozano',
#   'capitalismo',
#   'tardío',
#   'comandaba',
#   ',',
#   'auxiliado',
#   'incipientes',
#   'tecnologías',
#   'informáticas',
#   ',',
#   'salto',
#   'mercados',
#   'nacionales',
#   'mercado',
#   'global',
#   ',',
#   'economía',
#   'industrial',
#   'economía',
#   'financiera',
#   ',',
#   'socialdemocracia',
#   'neoliberalismo',
#   ',',
#   'canjes',
#   'fraguaron',
#   'tránsito',
#   'modernidad',
#   'posmodernidad',
#   '.'],
#  ['distopiland', 'cuenta', 'tanteos', 'prematuros', '.'],
#  ['sociólogo',
#   'fred',
#   'polak',
#   'notificó',
#   '1953',
#   'occidente',
#   'asistiendo',
#   '“',
#   'decadencia',
#   'imágenes',
#   'utópicas',
#   'futuro',
#   ',',
#   'reflejo',
#   'fe',
#   'perdida',
#   'fuerza',
#   'humana',
#   'libre',
#   'autodeterminación',
#   '”',
#   '.'],
#  ['coincidiendo',
#   'inicio',
#   'crisis',
#   'petróleo',
#   'publicación',
#   'límites',
#   'crecimiento',
#   'parte',
#   'club',
#   'roma',
#   ',',
#   'john',
#   'maddox',
#   ',',
#   'director',
#   'revista',
#   'nature',
#   ',',
#   'auscultó',
#   'primeros',
#   'indicios',
#   'distopofilia',
#   '.'],
#  ['corría', 'año', '1972', '.'],
#  ['riesgos',
#   'catapultaban',
#   'miedo',
#   'sociedad',
#   'época',
#   'superpoblación',
#   ',',
#   'ddt',
#   ',',
#   'ingeniería',
#   'genética',
#   ',',
#   'energía',
#   'atómica',
#   'agotamiento',
#   'alimentos',
#   ',',
#   'amenazas',
#   'rentabilizadas',
#   'ciencia',
#   'ficción',
#   'catastrofista',
#   'ensayos',
#   'superventas',
#   'paul',
#   'r.',
#   'ehrlich',
#   'barry',
#   'commoner',
#   ',',
#   'científicos',
#   'divulgación',
#   'propensos',
#   'alarmismo',
#   'sensacionalista',
#   '.'],
#  ['mente',
#   ',',
#   'maddox',
#   'decretó',
#   ':',
#   'profetas',
#   'desastre',
#   'multiplicado',
#   'notablemente',
#   'últimos',
#   'años',
#   '.'],
#  ['solía',
#   'haber',
#   'individuos',
#   'desfilaban',
#   'calles',
#   'ciudad',
#   'carteles',
#   'proclamaba',
#   ':',
#   '“',
#   '¡',
#   'fin',
#   'mundo',
#   'próximo',
#   '!',
#   '”',
#   '.'],
#  ['ahora',
#   'sido',
#   'reemplazados',
#   'legión',
#   'personas',
#   'serias',
#   ',',
#   'científicos',
#   ',',
#   'filósofos',
#   'políticos',
#   ',',
#   'proclaman',
#   'calamidades',
#   'sutiles',
#   'esperándonos',
#   'vuelta',
#   'esquina',
#   '.'],
#  ['distopización',
#   'imaginarios',
#   'tampoco',
#   'pasó',
#   'desapercibida',
#   'estudiosos',
#   'ciencia',
#   'ficción',
#   '.'],
#  ['kingsley',
#   'amis',
#   'publicó',
#   'new',
#   'maps',
#   'of',
#   'hell',
#   '(',
#   '1960',
#   ')',
#   ',',
#   'compilación',
#   'ensayos',
#   'vinculaba',
#   'supremacía',
#   'distópica',
#   'consternación',
#   'desatada',
#   'segunda',
#   'guerra',
#   'mundial',
#   'regímenes',
#   'hitler',
#   'stalin',
#   '.'],
#  ['dos',
#   'años',
#   'después',
#   ',',
#   'chad',
#   'walsh',
#   'informaba',
#   'from',
#   'utopia',
#   'to',
#   'nightmare',
#   '“',
#   'lector',
#   'busque',
#   'utopías',
#   'actuales',
#   ',',
#   'probablemente',
#   'encontrará',
#   'torpes',
#   'convincentes',
#   '.'],
#  ['si',
#   'quiere',
#   'pesadillas',
#   'presentadas',
#   'expertos',
#   ',',
#   'puede',
#   'elegir',
#   'variedad',
#   'horrores',
#   'mayor',
#   'descrita',
#   'dante',
#   '”',
#   '.'],
#  ['premisas',
#   'análogas',
#   'decoraron',
#   'the',
#   'future',
#   'as',
#   'nightmare',
#   '(',
#   '1967',
#   ')',
#   ',',
#   'mark',
#   'hillegas',
#   ',',
#   'science',
#   'fiction',
#   'and',
#   'the',
#   'new',
#   'dark',
#   'age',
#   '(',
#   '1976',
#   ')',
#   ',',
#   'harold',
#   'berger',
#   '.'],
#  ['ambos',
#   ',',
#   'apareció',
#   'historia',
#   'ciencia',
#   'ficción',
#   '(',
#   '1971',
#   ')',
#   ',',
#   'escritor',
#   'sam',
#   'lundway',
#   ',',
#   'leemos',
#   ':',
#   'escritores',
#   'ciencia',
#   'ficción',
#   'misántropos',
#   'incurables',
#   '.'],
#  ['podría',
#   'ser',
#   'resultado',
#   'inclinación',
#   'insólitamente',
#   'pesimista',
#   'gran',
#   'perspicacia',
#   ',',
#   'cierto',
#   'pocos',
#   'escritores',
#   'modernos',
#   'sf',
#   'hallan',
#   'razones',
#   'contemplar',
#   'futuro',
#   'gran',
#   'esperanza',
#   '[',
#   '…',
#   ']',
#   '.'],
#  ['futuro',
#   'resultará',
#   'ser',
#   'exactamente',
#   'propia',
#   'época',
#   '[',
#   '…',
#   ']',
#   ',',
#   'solo',
#   'peor',
#   '.'],
#  ['luego', 'reflejan', 'infierno', 'tierra', '.'],
#  ['cimentación',
#   'distopiland',
#   'recibió',
#   'espaldarazo',
#   'definitivo',
#   'nueve',
#   'noviembre',
#   '1989',
#   ',',
#   'día',
#   'produjo',
#   'caída',
#   'muro',
#   'berlín',
#   '.'],
#  ['utopía',
#   'sufrió',
#   'bofetada',
#   'brutal',
#   ',',
#   'pues',
#   'lance',
#   'parecía',
#   'ratificar',
#   'sueños',
#   'perfeccionamiento',
#   'emancipación',
#   'fracasado',
#   'duele',
#   ',',
#   'práctica',
#   '.'],
#  ['acontecimiento',
#   'aglutinó',
#   'simbólicamente',
#   'tropel',
#   'fracasos',
#   'vividos',
#   'movimientos',
#   'revolucionarios',
#   'pasado',
#   ',',
#   'fracasos',
#   ',',
#   'reunidos',
#   'golpe',
#   ',',
#   'manifestaron',
#   'intolerables',
#   ',',
#   'humillantes',
#   ',',
#   'imposibles',
#   'procesar',
#   '.'],
#  ['quedaba',
#   'ahí',
#   'dignidad',
#   'aureola',
#   'desprendidas',
#   'reveses',
#   'previos',
#   '(',
#   'comuna',
#   'parís',
#   ',',
#   'guerra',
#   'civil',
#   'española',
#   ',',
#   'mayo',
#   '68',
#   ',',
#   'gobierno',
#   'pinochet',
#   ')',
#   ',',
#   'capaces',
#   'dispensar',
#   'orgullo',
#   'incitar',
#   'afán',
#   'revancha',
#   '.'],
#  ['ocasión', ',', 'derrota', 'categórica', '.'],
#  ['escombros',
#   'taponaron',
#   'horizonte',
#   'utópico',
#   'socialista',
#   'conferido',
#   'esperanza',
#   'millones',
#   'personas',
#   '.'],
#  ['esperanza',
#   ',',
#   'decir',
#   'verdad',
#   ',',
#   'llegaba',
#   'menguada',
#   'causa',
#   'larga',
#   'secuencia',
#   'desengaños',
#   'estrenada',
#   'naturaleza',
#   'totalitaria',
#   'unión',
#   'soviética',
#   'prorrogada',
#   'represión',
#   'primavera',
#   'praga',
#   ',',
#   'matanzas',
#   'revolución',
#   'cultural',
#   'genocidio',
#   'camboya',
#   '.'],
#  ['lapsos',
#   'confiaron',
#   'transformar',
#   'mundo',
#   'enfermaron',
#   'estrés',
#   'postraumático',
#   'sobrevivieron',
#   'atormentados',
#   'duelo',
#   'culpa',
#   '.'],
#  ['resentidos',
#   'desmoralizados',
#   ',',
#   'cooperaron',
#   'desutopización',
#   'conciencia',
#   'política',
#   'consolidada',
#   'aquella',
#   'jornada',
#   ',',
#   'venganza',
#   'tardía',
#   'ilusiones',
#   'esgrimidas',
#   'juventud',
#   '.'],
#  ['puedes',
#   'seguir',
#   'babelia',
#   'facebook',
#   'twitter',
#   ',',
#   'apuntarte',
#   'aquí',
#   'recibir',
#   'newsletter',
#   'semanal',
#   '.']]

# %% [markdown]
# ### visualization

# %%
token_length = [len(x) for x in token_list]
token_length
# Out:
# [3,
#  20,
#  32,
#  12,
#  21,
#  16,
#  6,
#  28,
#  9,
#  18,
#  13,
#  27,
#  15,
#  4,
#  11,
#  5,
#  11,
#  13,
#  19,
#  20,
#  21,
#  14,
#  14,
#  20,
#  33,
#  15,
#  10,
#  15,
#  7,
#  4,
#  25,
#  6,
#  14,
#  9,
#  36,
#  32,
#  14,
#  17,
#  5,
#  9,
#  5,
#  7,
#  21,
#  10,
#  24,
#  33,
#  26,
#  20,
#  16,
#  30,
#  4,
#  45,
#  49,
#  44,
#  5,
#  22,
#  23,
#  4,
#  36,
#  12,
#  17,
#  19,
#  9,
#  25,
#  22,
#  15,
#  28,
#  22,
#  24,
#  13,
#  5,
#  15,
#  17,
#  23,
#  29,
#  5,
#  10,
#  27,
#  12,
#  17,
#  12]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
plt.figure(figsize=(12, 5))
plt.hist(token_length, bins=30, alpha=0.5, color='r', label='token', range=[1, np.max(token_length)])
# bins: 히스토그램 값들에 대한 버켓 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color: 그래프 색상
# label: 그래프에 대한 라벨
plt.title('Distribution of token length')
plt.legend()
plt.xlabel('number of tokens')
plt.ylabel('number of sentences')
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.boxplot(token_length,
           labels=['token count'], # 입력한 데이터에 대한 라벨
           showmeans=True) # 평균값을 마크함
plt.show()

# %%
token_list_all[:10] # 문장 경계 없는 리스트
# Out:
# ['arranquemos',
#  'cifras',
#  '.',
#  'the',
#  'guardian',
#  'informó',
#  '17',
#  'septiembre',
#  '2019',
#  'testamentos']

# %%
cloud = WordCloud(font_path='../data/NanumGothic.ttf',
                 width=800,
                 height=600).generate(' '.join(token_list_all))
plt.figure(figsize=(15, 10))
plt.imshow(cloud)
plt.axis('off')
plt.show()
